# %% [markdown]
# ## Spotify Stuff

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
spotify = pd.read_csv("msd_cleaned.csv")

# %%
spotify.head()
# Out:
#    SongNumber              SongID  AlbumID  \
# 0           1  SOMZWCG12A8C13C480   300848
# 1           2  SOCIWDW12A8C13D406   300822
# 2           3  SOXVLOJ12AB0189215   514953
# 3           4  SONHOTT12A8C13493C   287650
# 4           5  SOFSOCN12A8C143F5D   611336
#
#                              AlbumName            ArtistID        ArtistName  \
# 0                          Fear Itself  ARD7TVE1187B99BFB1            Casual
# 1                           Dimensions  ARMJAGH1187FB546F3      The Box Tops
# 2  Las Numero 1 De La Sonora Santanera  ARKRRTF1187B9984DA  Sonora Santanera
# 3                        Friend Or Foe  AR7G5I41187FB4CE6C          Adam Ant
# 4                        Muertos Vivos  ARXR32B1187FB57099               Gob
#
#     Duration  KeySignature    Tempo  TimeSignature             Title  Year  \
# 0  218.93179             1   92.198              4  I Didn't Mean To     0
# 1  148.03546             6  121.274              4         Soul Deep  1969
# 2  177.47546             8  100.070              1   Amor De Cabaret     0
# 3  233.40363             0  119.293              4   Something Girls  1982
# 4  209.60608             2  129.738              4    Face the Ashes  2007
#
#    SongHotness
# 0     0.602120
# 1          NaN
# 2          NaN
# 3          NaN
# 4     0.604501

# %%
spotify = spotify[["AlbumName", "ArtistName", "Duration", "KeySignature", "Tempo", "TimeSignature", "Title", "Year", "SongHotness"]]

# %%
spotify
# Out:
#                                 AlbumName                ArtistName  \
# 0                             Fear Itself                    Casual
# 1                              Dimensions              The Box Tops
# 2     Las Numero 1 De La Sonora Santanera          Sonora Santanera
# 3                           Friend Or Foe                  Adam Ant
# 4                           Muertos Vivos                       Gob
# ...                                   ...                       ...
# 9167                         Sin / Pecado                 Moonspell
# 9168                           Collection            Danny Williams
# 9169                              Reality             Winston Reedy
# 9170                       Nouveau Zydeco  Myrick "Freeze" Guillory
# 9171           Once Upon A Shattered Life       Seventh Day Slumber
#
#        Duration  KeySignature    Tempo  TimeSignature  \
# 0     218.93179             1   92.198              4
# 1     148.03546             6  121.274              4
# 2     177.47546             8  100.070              1
# 3     233.40363             0  119.293              4
# 4     209.60608             2  129.738              4
# ...         ...           ...      ...            ...
# 9167  386.19383             7  140.185              4
# 9168  168.01914             8   77.072              3
# 9169  193.72363             1  118.123              4
# 9170  300.82567             0  137.663              4
# 9171  209.73669             2  150.575              4
#
#                                  Title  Year  SongHotness
# 0                     I Didn't Mean To     0     0.602120
# 1                            Soul Deep  1969          NaN
# 2                      Amor De Cabaret     0          NaN
# 3                      Something Girls  1982          NaN
# 4                       Face the Ashes  2007     0.604501
# ...                                ...   ...          ...
# 9167                    The Hanged Man  1998     0.594080
# 9168  The Wonderful World Of The Young  1998     0.334707
# 9169                   Sentimental Man     0          NaN
# 9170                 Zydeco In D-Minor     0     0.000000
# 9171                    Shattered Life  2005     0.780312
#
# [9172 rows x 9 columns]

# %%
spotify.shape
# Out:
# (9172, 9)

# %%
spotify2 = spotify.dropna(subset=['SongHotness'])

# %%
spotify2.head()
# Out:
#         AlbumName        ArtistName   Duration  KeySignature    Tempo  \
# 0     Fear Itself            Casual  218.93179             1   92.198
# 4   Muertos Vivos               Gob  209.60608             2  129.738
# 8      Pink World  Planet P Project  269.81832             4   86.643
# 10     I Need You      JennyAnyKind  218.77506             5  146.765
# 11   The Way Home      Wayne Watson  245.21098             7  117.975
#
#     TimeSignature                     Title  Year  SongHotness
# 0               4          I Didn't Mean To     0     0.602120
# 4               4            Face the Ashes  2007     0.604501
# 8               4                Pink World  1984     0.265861
# 10              1           Young Boy Blues     0     0.000000
# 11              4  The Urgency (LP Version)     0     0.265861

# %%
spotify2_x = spotify2[["Tempo"]]

# %%
spotify2_y = spotify2[["SongHotness"]]

# %%
spotify3 = spotify[spotify['SongHotness'].isna()]

# %%
spotify3.head()
# Out:
#                              AlbumName             ArtistName   Duration  \
# 1                           Dimensions           The Box Tops  148.03546
# 2  Las Numero 1 De La Sonora Santanera       Sonora Santanera  177.47546
# 3                        Friend Or Foe               Adam Ant  233.40363
# 5                         Ordinary Day  Jeff And Sheri Easter  267.70240
# 6                    Da Ghetto Psychic                Rated R  114.78159
#
#    KeySignature    Tempo  TimeSignature  \
# 1             6  121.274              4
# 2             8  100.070              1
# 3             0  119.293              4
# 5             5  147.782              3
# 6             1  111.787              1
#
#                                          Title  Year  SongHotness
# 1                                    Soul Deep  1969          NaN
# 2                              Amor De Cabaret     0          NaN
# 3                              Something Girls  1982          NaN
# 5  The Moon And I (Ordinary Day Album Version)     0          NaN
# 6                        Keepin It Real (Skit)     0          NaN

# %%
from sklearn.linear_model import LinearRegression

# %%
x = spotify2_x.to_numpy()
y = spotify2_y.to_numpy()

# %%
reg = LinearRegression().fit(x, y)
reg.score(x, y)
# Out:
# 0.007514597266787826

# %%
import spotify

# %%
a = spotify.read_song_data()

# %%
print(a)
# Out:
# [<spotify.Song object at 0x0000011D9CB62B20>, <spotify.Song object at 0x0000011D9CB62FD0>, <spotify.Song object at 0x0000011D9CB62880>, <spotify.Song object at 0x0000011D9CB62DF0>, <spotify.Song object at 0x0000011D9CB62EB0>, <spotify.Song object at 0x0000011D9CB62F10>, <spotify.Song object at 0x0000011D9CB626D0>, <spotify.Song object at 0x0000011D9CB626A0>, <spotify.Song object at 0x0000011D9CB62A90>, <spotify.Song object at 0x0000011D9CB625E0>, <spotify.Song object at 0x0000011D9CB625B0>, <spotify.Song object at 0x0000011D9CB62580>, <spotify.Song object at 0x0000011D9CB62550>, <spotify.Song object at 0x0000011D9CB62520>, <spotify.Song object at 0x0000011D9CB624F0>, <spotify.Song object at 0x0000011D9CB624C0>, <spotify.Song object at 0x0000011D9CB62490>, <spotify.Song object at 0x0000011D9CB62460>, <spotify.Song object at 0x0000011D9CB62430>, <spotify.Song object at 0x0000011D9CB62400>, <spotify.Song object at 0x0000011D9CB623D0>, <spotify.Song object at 0x0000011D9CB623A0>, <spotify.Song object at 0x0000011D9CB62370>, <spotify.Song object at 0x0000011D9CB62340>, <spotify.Song object at 0x0000011D9CB62310>, <spotify.Song object at 0x0000011D9CB622E0>, <sp